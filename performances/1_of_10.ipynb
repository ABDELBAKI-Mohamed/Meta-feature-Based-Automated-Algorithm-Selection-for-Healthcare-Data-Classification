# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.utils import shuffle
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import AdaBoostClassifier
import json

# %%
with open('../datasets/index.json', 'r') as file:
    files = json.load(file)

# %%
algorithms = {
    #svm.SVC(kernel='linear'): 'Support Vector Machines (SVM)',
    KNeighborsClassifier(n_neighbors=3): 'KNN',
    LogisticRegression(): 'LR',
    #DecisionTreeClassifier(): 'Decision Trees',
    RandomForestClassifier(): 'RF',
    GaussianNB(): 'NB',
    GradientBoostingClassifier(): 'GB',
    #MLPClassifier(): 'MLP',
    AdaBoostClassifier(): 'ADA'
}

# %%
performances = []

for file in files:

    dataset = pd.read_csv(f"../datasets/{file['file']}")

    X = dataset.drop(file["target"],axis=1)
    y = dataset[file["target"]]

    n_splits = 1

    splitted = False

    if len(X)>15000 or len(X)<900:
        continue
    
    n_splits = 10
    stratified_kfold = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=33)
    splits = stratified_kfold.split(X, y)
    splits_array = [b for a,b in splits]
    splitted = True

    for split in range(n_splits):

        X_split, y_split = X, y

        if splitted:
            X_split, y_split = X.iloc[splits_array[split]], y.iloc[splits_array[split]]

        performance = {'dataset':f"{file['name']}_{split+1}_of_{n_splits}"}

        for algorithm, algorithm_name in algorithms.items():

            print(algorithm_name)

            stratified_kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=33)

            accuracies = cross_val_score(algorithm, X_split, y_split, cv=stratified_kfold)
            
            performance[algorithm_name] = accuracies.mean()

        print(performance)
        performances.append(performance)
# Out:
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'symptoms_1_of_10', 'KNN': 0.8841269841269842, 'LR': 0.833353947639662, 'RF': 0.9512059369202227, 'NB': 0.8516594516594516, 'GB': 0.9349824778396207, 'ADA': 0.07318078746650175}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'symptoms_2_of_10', 'KNN': 0.8882498453927026, 'LR': 0.8516594516594516, 'RF': 0.9472273757988043, 'NB': 0.8741496598639455, 'GB': 0.9431869717584004, 'ADA': 0.0670995670995671}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'symptoms_3_of_10', 'KNN': 0.900247371675943, 'LR': 0.8881467738610596, 'RF': 0.9533292104720676, 'NB': 0.8638425066996496, 'GB': 0.9553494124922697, 'ADA': 0.07520098948670377}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'symptoms_4_of_10', 'KNN': 0.8943104514533087, 'LR': 0.8556586270871985, 'RF': 0.9532261389404246, 'NB': 0.8780457637600495, 'GB': 0.9511853226138941, 'ADA': 0.08536384250669964}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'symptoms_5_of_10', 'KNN': 0.9003916718202433, 'LR': 0.8454545454545455, 'RF': 0.9614100185528758, 'NB': 0.8048237476808906, 'GB': 0.9532261389404246, 'ADA': 0.07926200783343641}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'symptoms_6_of_10', 'KNN': 0.8821067821067821, 'LR': 0.8476190476190476, 'RF': 0.9694702123273553, 'NB': 0.8413522984951557, 'GB': 0.9491445062873634, 'ADA': 0.07316017316017316}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'symptoms_7_of_10', 'KNN': 0.8963100391671819, 'LR': 0.8435168006596578, 'RF': 0.9633889919604204, 'NB': 0.8393114821686251, 'GB': 0.9450834879406308, 'ADA': 0.0813440527726242}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'symptoms_8_of_10', 'KNN': 0.9004329004329005, 'LR': 0.882209853638425, 'RF': 0.957349000206143, 'NB': 0.8577819006390435, 'GB': 0.9491857349000206, 'ADA': 0.07932385075242218}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'symptoms_9_of_10', 'KNN': 0.9044114615543186, 'LR': 0.8434137291280148, 'RF': 0.9572253143681715, 'NB': 0.8312306740878169, 'GB': 0.9388785817357247, 'ADA': 0.08738404452690166}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'symptoms_10_of_10', 'KNN': 0.8902082044939188, 'LR': 0.8637600494743352, 'RF': 0.9572871572871573, 'NB': 0.8515976087404658, 'GB': 0.9491651205936922, 'ADA': 0.08542568542568543}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'stroke_1_of_10', 'KNN': 0.9471730439748715, 'LR': 0.9491147915476871, 'RF': 0.9510755758614126, 'NB': 0.8747382448124881, 'GB': 0.9354273748334286, 'ADA': 0.9334665905197032}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'stroke_2_of_10', 'KNN': 0.9295069484104321, 'LR': 0.9451932229202361, 'RF': 0.9510755758614126, 'NB': 0.6105844279459356, 'GB': 0.9373500856653341, 'ADA': 0.937369122406244}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'stroke_3_of_10', 'KNN': 0.9354083380925186, 'LR': 0.9451932229202361, 'RF': 0.9471730439748715, 'NB': 0.8434799162383401, 'GB': 0.9451932229202361, 'ADA': 0.933504664001523}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'stroke_4_of_10', 'KNN': 0.9393299067199695, 'LR': 0.9471540072339616, 'RF': 0.9471730439748715, 'NB': 0.8845421663811155, 'GB': 0.9197411003236248, 'ADA': 0.9373881591471541}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'stroke_5_of_10', 'KNN': 0.9334475537787931, 'LR': 0.9491338282885969, 'RF': 0.9510755758614126, 'NB': 0.8728155339805825, 'GB': 0.9373881591471541, 'ADA': 0.9413097277746051}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'stroke_6_of_10', 'KNN': 0.9393489434608796, 'LR': 0.9471730439748715, 'RF': 0.9471540072339616, 'NB': 0.8669141442984962, 'GB': 0.9393299067199695, 'ADA': 0.9275842375785267}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'stroke_7_of_10', 'KNN': 0.9471349704930516, 'LR': 0.9471540072339616, 'RF': 0.9510755758614126, 'NB': 0.8138968208642681, 'GB': 0.9432134018656007, 'ADA': 0.9255853797829812}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'stroke_8_of_10', 'KNN': 0.9432514753474207, 'LR': 0.9491147915476871, 'RF': 0.9491147915476871, 'NB': 0.8707976394441271, 'GB': 0.9412716542927851, 'ADA': 0.9314867694650676}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'stroke_9_of_10', 'KNN': 0.9373881591471541, 'LR': 0.9432514753474205, 'RF': 0.9491147915476871, 'NB': 0.8786407766990291, 'GB': 0.9393489434608796, 'ADA': 0.9295450218922522}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'stroke_10_of_10', 'KNN': 0.9510375023795927, 'LR': 0.9510755758614126, 'RF': 0.953036360175138, 'NB': 0.8746811345897582, 'GB': 0.9510755758614126, 'ADA': 0.9529792499524081}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'heartDisease_1_of_10', 'KNN': 0.749122807017544, 'LR': 0.8608187134502924, 'RF': 0.7842105263157895, 'NB': 0.8491228070175438, 'GB': 0.7403508771929825, 'ADA': 0.8157894736842104}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'heartDisease_2_of_10', 'KNN': 0.6742690058479532, 'LR': 0.8245614035087719, 'RF': 0.8894736842105262, 'NB': 0.802923976608187, 'GB': 0.8350877192982455, 'ADA': 0.7614035087719299}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'heartDisease_3_of_10', 'KNN': 0.5549707602339182, 'LR': 0.7368421052631579, 'RF': 0.7374269005847953, 'NB': 0.8035087719298246, 'GB': 0.6941520467836257, 'ADA': 0.6175438596491227}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'heartDisease_4_of_10', 'KNN': 0.7052631578947368, 'LR': 0.8269005847953217, 'RF': 0.9023391812865498, 'NB': 0.8923976608187134, 'GB': 0.8923976608187134, 'ADA': 0.8052631578947368}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'heartDisease_5_of_10', 'KNN': 0.5666666666666667, 'LR': 0.8368421052631578, 'RF': 0.9239766081871345, 'NB': 0.8807017543859649, 'GB': 0.8578947368421053, 'ADA': 0.8169590643274853}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'heartDisease_6_of_10', 'KNN': 0.6736842105263158, 'LR': 0.8263157894736842, 'RF': 0.7935672514619883, 'NB': 0.8385964912280702, 'GB': 0.750877192982456, 'ADA': 0.7497076023391813}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'heartDisease_7_of_10', 'KNN': 0.6105263157894737, 'LR': 0.8163742690058479, 'RF': 0.8374269005847953, 'NB': 0.8695906432748538, 'GB': 0.8175438596491228, 'ADA': 0.7719298245614035}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'heartDisease_8_of_10', 'KNN': 0.6292397660818713, 'LR': 0.85906432748538, 'RF': 0.8485380116959064, 'NB': 0.8280701754385966, 'GB': 0.8596491228070174, 'ADA': 0.8818713450292396}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'heartDisease_9_of_10', 'KNN': 0.6152046783625732, 'LR': 0.8350877192982455, 'RF': 0.802923976608187, 'NB': 0.8023391812865498, 'GB': 0.7695906432748538, 'ADA': 0.7473684210526315}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'heartDisease_10_of_10', 'KNN': 0.5257309941520468, 'LR': 0.760233918128655, 'RF': 0.747953216374269, 'NB': 0.7584795321637426, 'GB': 0.7140350877192982, 'ADA': 0.6152046783625731}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'hypothyroid_1_of_10', 'KNN': 0.9005405405405404, 'LR': 0.9141261261261262, 'RF': 0.9327567567567566, 'NB': 0.33599999999999997, 'GB': 0.9705585585585587, 'ADA': 0.9731171171171171}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'hypothyroid_2_of_10', 'KNN': 0.9163963963963964, 'LR': 0.9191711711711712, 'RF': 0.9353513513513514, 'NB': 0.4259459459459459, 'GB': 0.9623423423423425, 'ADA': 0.9596756756756758}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'hypothyroid_3_of_10', 'KNN': 0.9003243243243242, 'LR': 0.9272432432432434, 'RF': 0.9245405405405405, 'NB': 0.3936936936936937, 'GB': 0.9380540540540541, 'ADA': 0.9541981981981982}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'hypothyroid_4_of_10', 'KNN': 0.8948828828828829, 'LR': 0.9218378378378379, 'RF': 0.921873873873874, 'NB': 0.29387387387387387, 'GB': 0.9138738738738738, 'ADA': 0.9057297297297298}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'hypothyroid_5_of_10', 'KNN': 0.9137657657657657, 'LR': 0.9164324324324324, 'RF': 0.9272432432432431, 'NB': 0.390990990990991, 'GB': 0.9595675675675676, 'ADA': 0.9595675675675676}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'hypothyroid_6_of_10', 'KNN': 0.9109909909909911, 'LR': 0.9245045045045046, 'RF': 0.9407207207207208, 'NB': 0.36111711711711714, 'GB': 0.9541981981981982, 'ADA': 0.9487927927927927}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'hypothyroid_7_of_10', 'KNN': 0.9137297297297298, 'LR': 0.9244684684684685, 'RF': 0.929873873873874, 'NB': 0.34248648648648644, 'GB': 0.9407207207207208, 'ADA': 0.962234234234234}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'hypothyroid_8_of_10', 'KNN': 0.902954954954955, 'LR': 0.9326126126126125, 'RF': 0.9299459459459459, 'NB': 0.3476396396396397, 'GB': 0.9515315315315316, 'ADA': 0.964972972972973}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'hypothyroid_9_of_10', 'KNN': 0.8948468468468468, 'LR': 0.9137297297297297, 'RF': 0.9299099099099098, 'NB': 0.3532612612612613, 'GB': 0.9784504504504504, 'ADA': 0.9784144144144145}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'hypothyroid_10_of_10', 'KNN': 0.8921801801801802, 'LR': 0.9165405405405405, 'RF': 0.9191711711711712, 'NB': 0.34490090090090086, 'GB': 0.9542702702702703, 'ADA': 0.9489009009009008}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'framingham_1_of_10', 'KNN': 0.81965938541281, 'LR': 0.8415401703072936, 'RF': 0.8333209922251019, 'NB': 0.8058496853017401, 'GB': 0.8250647908182154, 'ADA': 0.8031840059237318}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'framingham_2_of_10', 'KNN': 0.811477230655313, 'LR': 0.8470936690114772, 'RF': 0.8334320621991853, 'NB': 0.7979266938171048, 'GB': 0.8142910033320993, 'ADA': 0.7950758978156238}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'framingham_3_of_10', 'KNN': 0.81965938541281, 'LR': 0.8552017771195853, 'RF': 0.838837467604591, 'NB': 0.7790077748981858, 'GB': 0.8115142539800073, 'ADA': 0.7788226582747131}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'framingham_4_of_10', 'KNN': 0.8006664198445019, 'LR': 0.8415401703072936, 'RF': 0.8387263976305073, 'NB': 0.8415031469825991, 'GB': 0.8442798963346909, 'ADA': 0.8115512773047019}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'framingham_5_of_10', 'KNN': 0.8251018141429102, 'LR': 0.8388004442798962, 'RF': 0.8333209922251019, 'NB': 0.7349129951869677, 'GB': 0.8224361347649018, 'ADA': 0.8169196593854128}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'framingham_6_of_10', 'KNN': 0.8279155868196962, 'LR': 0.8442798963346908, 'RF': 0.8333209922251017, 'NB': 0.8004442798963346, 'GB': 0.8333209922251019, 'ADA': 0.8059607552758237}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'framingham_7_of_10', 'KNN': 0.821917808219178, 'LR': 0.8438356164383561, 'RF': 0.841095890410959, 'NB': 0.8191780821917808, 'GB': 0.8219178082191781, 'ADA': 0.7808219178082192}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'framingham_8_of_10', 'KNN': 0.8219178082191781, 'LR': 0.841095890410959, 'RF': 0.8301369863013699, 'NB': 0.8383561643835616, 'GB': 0.8246575342465754, 'ADA': 0.7917808219178082}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'framingham_9_of_10', 'KNN': 0.8027397260273972, 'LR': 0.8438356164383561, 'RF': 0.8493150684931507, 'NB': 0.8301369863013699, 'GB': 0.8301369863013697, 'ADA': 0.8}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'framingham_10_of_10', 'KNN': 0.8, 'LR': 0.8602739726027396, 'RF': 0.8301369863013699, 'NB': 0.7890410958904109, 'GB': 0.8164383561643836, 'ADA': 0.8191780821917808}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'heartBeat_1_of_10', 'KNN': 0.9993127147766323, 'LR': 0.9608647554488539, 'RF': 0.9883302735018595, 'NB': 0.7596267005601846, 'GB': 1.0, 'ADA': 1.0}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'heartBeat_2_of_10', 'KNN': 1.0, 'LR': 0.9697900484865603, 'RF': 0.986948641905569, 'NB': 0.7630584192439862, 'GB': 1.0, 'ADA': 1.0}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'heartBeat_3_of_10', 'KNN': 0.9993127147766323, 'LR': 0.9800687285223368, 'RF': 0.9876288659793815, 'NB': 0.7793814432989692, 'GB': 0.9986254295532646, 'ADA': 0.9986254295532646}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'heartBeat_4_of_10', 'KNN': 1.0, 'LR': 0.9800687285223366, 'RF': 0.9896907216494846, 'NB': 0.7360824742268042, 'GB': 1.0, 'ADA': 1.0}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'heartBeat_5_of_10', 'KNN': 1.0, 'LR': 0.9752577319587628, 'RF': 0.9890034364261169, 'NB': 0.7656357388316152, 'GB': 1.0, 'ADA': 1.0}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'heartBeat_6_of_10', 'KNN': 0.9993127147766323, 'LR': 0.9814432989690722, 'RF': 0.9938144329896907, 'NB': 0.7223367697594502, 'GB': 0.9993127147766323, 'ADA': 0.9993127147766323}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'heartBeat_7_of_10', 'KNN': 1.0, 'LR': 0.9642611683848796, 'RF': 0.9917525773195877, 'NB': 0.7731958762886597, 'GB': 0.9986254295532646, 'ADA': 0.9986254295532646}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'heartBeat_8_of_10', 'KNN': 1.0, 'LR': 0.9704467353951889, 'RF': 0.9883161512027492, 'NB': 0.7676975945017182, 'GB': 0.9986254295532646, 'ADA': 0.9986254295532646}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'heartBeat_9_of_10', 'KNN': 1.0, 'LR': 0.9821305841924399, 'RF': 0.9917525773195877, 'NB': 0.7807560137457045, 'GB': 1.0, 'ADA': 1.0}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'heartBeat_10_of_10', 'KNN': 0.9993127147766323, 'LR': 0.9711340206185566, 'RF': 0.9876288659793815, 'NB': 0.770446735395189, 'GB': 0.9993127147766323, 'ADA': 0.9993127147766323}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'fetalHealth_1_of_10', 'KNN': 0.8217054263565892, 'LR': 0.8499446290143965, 'RF': 0.8919158361018826, 'NB': 0.7466223698781839, 'GB': 0.9059800664451828, 'ADA': 0.8403100775193797}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'fetalHealth_2_of_10', 'KNN': 0.8264673311184939, 'LR': 0.8452934662236988, 'RF': 0.8780730897009967, 'NB': 0.7748615725359912, 'GB': 0.8966777408637874, 'ADA': 0.8031007751937983}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'fetalHealth_3_of_10', 'KNN': 0.8169435215946844, 'LR': 0.8821705426356589, 'RF': 0.8966777408637873, 'NB': 0.7459579180509414, 'GB': 0.896345514950166, 'ADA': 0.8310077519379846}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'fetalHealth_4_of_10', 'KNN': 0.8403100775193797, 'LR': 0.8730897009966776, 'RF': 0.8964562569213731, 'NB': 0.7984496124031008, 'GB': 0.8732004429678849, 'ADA': 0.8028792912513844}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'fetalHealth_5_of_10', 'KNN': 0.8219269102990033, 'LR': 0.8637873754152825, 'RF': 0.92015503875969, 'NB': 0.7561461794019932, 'GB': 0.887264673311185, 'ADA': 0.7094130675526025}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'fetalHealth_6_of_10', 'KNN': 0.7983388704318938, 'LR': 0.8830564784053155, 'RF': 0.892358803986711, 'NB': 0.84562569213732, 'GB': 0.9016611295681063, 'ADA': 0.8829457364341085}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'fetalHealth_7_of_10', 'KNN': 0.8160575858250277, 'LR': 0.8675526024363233, 'RF': 0.9058693244739755, 'NB': 0.816389811738649, 'GB': 0.9151716500553709, 'ADA': 0.7604651162790697}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'fetalHealth_8_of_10', 'KNN': 0.816389811738649, 'LR': 0.8306755260243633, 'RF': 0.8777408637873755, 'NB': 0.7305647840531562, 'GB': 0.8679955703211517, 'ADA': 0.8491694352159469}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'fetalHealth_9_of_10', 'KNN': 0.8870431893687709, 'LR': 0.8676633444075306, 'RF': 0.9291251384274639, 'NB': 0.839424141749723, 'GB': 0.934108527131783, 'ADA': 0.9056478405315614}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'fetalHealth_10_of_10', 'KNN': 0.8111849390919159, 'LR': 0.8726467331118494, 'RF': 0.9058693244739755, 'NB': 0.8255813953488371, 'GB': 0.93421926910299, 'ADA': 0.9058693244739757}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'fetalCardio_1_of_10', 'KNN': 0.7748615725359912, 'LR': 0.7648947951273533, 'RF': 0.8120708748615725, 'NB': 0.7559246954595792, 'GB': 0.8121816168327797, 'ADA': 0.8122923588039868}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'fetalCardio_2_of_10', 'KNN': 0.7610188261351052, 'LR': 0.7697674418604651, 'RF': 0.8549280177187153, 'NB': 0.6671096345514951, 'GB': 0.8688815060908084, 'ADA': 0.7744186046511627}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'fetalCardio_3_of_10', 'KNN': 0.7741971207087486, 'LR': 0.8023255813953488, 'RF': 0.8593576965669989, 'NB': 0.7887043189368771, 'GB': 0.8308970099667775, 'ADA': 0.8173864894795126}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'fetalCardio_4_of_10', 'KNN': 0.774640088593577, 'LR': 0.8117386489479512, 'RF': 0.8452934662236988, 'NB': 0.807530454042082, 'GB': 0.8452934662236988, 'ADA': 0.7744186046511627}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'fetalCardio_5_of_10', 'KNN': 0.7842746400885936, 'LR': 0.7794019933554817, 'RF': 0.8261351052048725, 'NB': 0.7231450719822814, 'GB': 0.8358803986710963, 'ADA': 0.7840531561461794}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'fetalCardio_6_of_10', 'KNN': 0.8407530454042081, 'LR': 0.8358803986710963, 'RF': 0.8966777408637874, 'NB': 0.873421926910299, 'GB': 0.8641196013289036, 'ADA': 0.8310077519379846}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'fetalCardio_7_of_10', 'KNN': 0.7357696566998893, 'LR': 0.8021040974529345, 'RF': 0.8489479512735327, 'NB': 0.8347729789590254, 'GB': 0.8254706533776301, 'ADA': 0.8159468438538205}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'fetalCardio_8_of_10', 'KNN': 0.7736434108527132, 'LR': 0.7924695459579181, 'RF': 0.8537098560354375, 'NB': 0.7589147286821706, 'GB': 0.8537098560354375, 'ADA': 0.8304540420819491}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'fetalCardio_9_of_10', 'KNN': 0.849501661129568, 'LR': 0.835548172757475, 'RF': 0.9293466223698783, 'NB': 0.7310077519379845, 'GB': 0.8965669988925802, 'ADA': 0.8776301218161684}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'fetalCardio_10_of_10', 'KNN': 0.7678848283499446, 'LR': 0.8396456256921372, 'RF': 0.863233665559247, 'NB': 0.7314507198228128, 'GB': 0.8349944629014395, 'ADA': 0.7541528239202658}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'diabetes2019_1_of_10', 'KNN': 0.6142105263157894, 'LR': 0.8131578947368421, 'RF': 0.8347368421052632, 'NB': 0.8231578947368421, 'GB': 0.8236842105263158, 'ADA': 0.7926315789473685}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'diabetes2019_2_of_10', 'KNN': 0.6147368421052631, 'LR': 0.8326315789473684, 'RF': 0.8121052631578948, 'NB': 0.748421052631579, 'GB': 0.8642105263157894, 'ADA': 0.811578947368421}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'diabetes2019_3_of_10', 'KNN': 0.7473684210526317, 'LR': 0.9263157894736842, 'RF': 0.8842105263157893, 'NB': 0.8421052631578949, 'GB': 0.8842105263157896, 'ADA': 0.8631578947368421}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'diabetes2019_4_of_10', 'KNN': 0.6421052631578947, 'LR': 0.8526315789473685, 'RF': 0.8315789473684211, 'NB': 0.7894736842105263, 'GB': 0.8736842105263157, 'ADA': 0.8210526315789473}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'diabetes2019_5_of_10', 'KNN': 0.6947368421052632, 'LR': 0.8421052631578949, 'RF': 0.8842105263157893, 'NB': 0.7368421052631579, 'GB': 0.8736842105263157, 'ADA': 0.8105263157894738}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'diabetes2019_6_of_10', 'KNN': 0.7578947368421052, 'LR': 0.8, 'RF': 0.7473684210526315, 'NB': 0.7789473684210526, 'GB': 0.8, 'ADA': 0.8}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'diabetes2019_7_of_10', 'KNN': 0.6105263157894737, 'LR': 0.7684210526315789, 'RF': 0.7894736842105263, 'NB': 0.7368421052631579, 'GB': 0.6842105263157894, 'ADA': 0.7157894736842104}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'diabetes2019_8_of_10', 'KNN': 0.6526315789473683, 'LR': 0.9052631578947368, 'RF': 0.9263157894736842, 'NB': 0.6736842105263158, 'GB': 0.8631578947368421, 'ADA': 0.8736842105263157}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'diabetes2019_9_of_10', 'KNN': 0.7578947368421052, 'LR': 0.8105263157894737, 'RF': 0.8315789473684211, 'NB': 0.7157894736842106, 'GB': 0.8210526315789475, 'ADA': 0.8}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'diabetes2019_10_of_10', 'KNN': 0.7052631578947369, 'LR': 0.8421052631578947, 'RF': 0.8210526315789473, 'NB': 0.7894736842105263, 'GB': 0.8315789473684211, 'ADA': 0.8105263157894737}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'epilepsy_1_of_10', 'KNN': 0.8817391304347826, 'LR': 0.5478260869565218, 'RF': 0.9565217391304348, 'NB': 0.9608695652173914, 'GB': 0.9547826086956522, 'ADA': 0.9513043478260869}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'epilepsy_2_of_10', 'KNN': 0.877391304347826, 'LR': 0.5739130434782609, 'RF': 0.9617391304347827, 'NB': 0.9626086956521739, 'GB': 0.9486956521739129, 'ADA': 0.942608695652174}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'epilepsy_3_of_10', 'KNN': 0.8765217391304347, 'LR': 0.5982608695652174, 'RF': 0.9608695652173914, 'NB': 0.9643478260869565, 'GB': 0.9495652173913044, 'ADA': 0.9513043478260869}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'epilepsy_4_of_10', 'KNN': 0.8800000000000001, 'LR': 0.5956521739130436, 'RF': 0.953913043478261, 'NB': 0.9478260869565218, 'GB': 0.9504347826086956, 'ADA': 0.9278260869565218}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'epilepsy_5_of_10', 'KNN': 0.8730434782608695, 'LR': 0.548695652173913, 'RF': 0.953913043478261, 'NB': 0.9486956521739132, 'GB': 0.9452173913043479, 'ADA': 0.9391304347826088}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'epilepsy_6_of_10', 'KNN': 0.8643478260869566, 'LR': 0.5965217391304347, 'RF': 0.9600000000000002, 'NB': 0.9608695652173912, 'GB': 0.9591304347826087, 'ADA': 0.9582608695652175}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'epilepsy_7_of_10', 'KNN': 0.8869565217391304, 'LR': 0.5747826086956522, 'RF': 0.9565217391304348, 'NB': 0.9669565217391305, 'GB': 0.9478260869565218, 'ADA': 0.9339130434782609}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'epilepsy_8_of_10', 'KNN': 0.8730434782608695, 'LR': 0.5721739130434783, 'RF': 0.9530434782608695, 'NB': 0.9521739130434783, 'GB': 0.9495652173913044, 'ADA': 0.9373913043478261}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'epilepsy_9_of_10', 'KNN': 0.8791304347826088, 'LR': 0.5982608695652174, 'RF': 0.9539130434782608, 'NB': 0.9565217391304348, 'GB': 0.942608695652174, 'ADA': 0.9339130434782608}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'epilepsy_10_of_10', 'KNN': 0.8634782608695654, 'LR': 0.5652173913043478, 'RF': 0.9617391304347827, 'NB': 0.9591304347826087, 'GB': 0.9608695652173914, 'ADA': 0.9443478260869567}

# %%
performances_df = pd.DataFrame(performances)
performances_df
# Out:
#               dataset       KNN        LR        RF        NB        GB  \
# 0    symptoms_1_of_10  0.884127  0.833354  0.951206  0.851659  0.934982
# 1    symptoms_2_of_10  0.888250  0.851659  0.947227  0.874150  0.943187
# 2    symptoms_3_of_10  0.900247  0.888147  0.953329  0.863843  0.955349
# 3    symptoms_4_of_10  0.894310  0.855659  0.953226  0.878046  0.951185
# 4    symptoms_5_of_10  0.900392  0.845455  0.961410  0.804824  0.953226
# ..                ...       ...       ...       ...       ...       ...
# 95   epilepsy_6_of_10  0.864348  0.596522  0.960000  0.960870  0.959130
# 96   epilepsy_7_of_10  0.886957  0.574783  0.956522  0.966957  0.947826
# 97   epilepsy_8_of_10  0.873043  0.572174  0.953043  0.952174  0.949565
# 98   epilepsy_9_of_10  0.879130  0.598261  0.953913  0.956522  0.942609
# 99  epilepsy_10_of_10  0.863478  0.565217  0.961739  0.959130  0.960870
#
#          ADA
# 0   0.073181
# 1   0.067100
# 2   0.075201
# 3   0.085364
# 4   0.079262
# ..       ...
# 95  0.958261
# 96  0.933913
# 97  0.937391
# 98  0.933913
# 99  0.944348
#
# [100 rows x 7 columns]

# %%
def reorder(row, columns):
    sorted_index = row.loc[columns].sort_values(ascending=False).index
    new_columns = [f'v{i}' for i in range(1, len(sorted_index) + 1)]
    return pd.Series(sorted_index.values, index=new_columns)

# %%
performance_df_sorted = performances_df.apply(reorder, axis=1, columns=performances_df.columns[1:])
performance_df_sorted = pd.concat([performances_df[['dataset']], performance_df_sorted], axis=1)
performance_df_sorted
# Out:
#               dataset  v1  v2   v3   v4   v5   v6
# 0    symptoms_1_of_10  RF  GB  KNN   NB   LR  ADA
# 1    symptoms_2_of_10  RF  GB  KNN   NB   LR  ADA
# 2    symptoms_3_of_10  GB  RF  KNN   LR   NB  ADA
# 3    symptoms_4_of_10  RF  GB  KNN   NB   LR  ADA
# 4    symptoms_5_of_10  RF  GB  KNN   LR   NB  ADA
# ..                ...  ..  ..  ...  ...  ...  ...
# 95   epilepsy_6_of_10  NB  RF   GB  ADA  KNN   LR
# 96   epilepsy_7_of_10  NB  RF   GB  ADA  KNN   LR
# 97   epilepsy_8_of_10  RF  NB   GB  ADA  KNN   LR
# 98   epilepsy_9_of_10  NB  RF   GB  ADA  KNN   LR
# 99  epilepsy_10_of_10  RF  GB   NB  ADA  KNN   LR
#
# [100 rows x 7 columns]

# %%
performance_df_sorted['v1'].value_counts()
# Out:
# RF     42
# GB     18
# LR     16
# NB      9
# KNN     9
# ADA     6
# Name: v1, dtype: int64

# %%
performances_df.to_csv(f'../performances/splitted/1_of_{n_splits}.csv',index=False)
performance_df_sorted.to_csv(f'../performances/splitted/1_of_{n_splits}_sort.csv',index=False)
