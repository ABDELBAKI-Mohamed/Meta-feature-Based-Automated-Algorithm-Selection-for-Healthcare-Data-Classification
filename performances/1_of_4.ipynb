# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.utils import shuffle
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import AdaBoostClassifier
import json

# %%
with open('../datasets/index.json', 'r') as file:
    files = json.load(file)

# %%
algorithms = {
    #svm.SVC(kernel='linear'): 'Support Vector Machines (SVM)',
    KNeighborsClassifier(n_neighbors=3): 'KNN',
    LogisticRegression(): 'LR',
    #DecisionTreeClassifier(): 'Decision Trees',
    RandomForestClassifier(): 'RF',
    GaussianNB(): 'NB',
    GradientBoostingClassifier(): 'GB',
    #MLPClassifier(): 'MLP',
    AdaBoostClassifier(): 'ADA'
}

# %%
performances = []

for file in files:

    dataset = pd.read_csv(f"../datasets/{file['file']}")

    X = dataset.drop(file["target"],axis=1)
    y = dataset[file["target"]]

    n_splits = 1

    splitted = False

    if len(X)>15000 or len(X)<400:
        continue
    
    n_splits = 4
    stratified_kfold = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=33)
    splits = stratified_kfold.split(X, y)
    splits_array = [b for a,b in splits]
    splitted = True

    for split in range(n_splits):

        X_split, y_split = X, y

        if splitted:
            X_split, y_split = X.iloc[splits_array[split]], y.iloc[splits_array[split]]

        performance = {'dataset':f"{file['name']}_{split+1}_of_{n_splits}"}

        for algorithm, algorithm_name in algorithms.items():

            print(algorithm_name)

            stratified_kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=33)

            accuracies = cross_val_score(algorithm, X_split, y_split, cv=stratified_kfold)
            
            performance[algorithm_name] = accuracies.mean()

        print(performance)
        performances.append(performance)
# Out:
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'diabetes_1_of_4', 'KNN': 0.7133603238866397, 'LR': 0.7802968960863698, 'RF': 0.7489878542510121, 'NB': 0.7699055330634279, 'GB': 0.7492577597840755, 'ADA': 0.7443994601889339}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'diabetes_2_of_4', 'KNN': 0.7133603238866397, 'LR': 0.7136302294197032, 'RF': 0.7507422402159245, 'NB': 0.7554655870445345, 'GB': 0.7346828609986505, 'ADA': 0.7139001349527665}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'diabetes_3_of_4', 'KNN': 0.7238866396761134, 'LR': 0.7502024291497976, 'RF': 0.7709851551956814, 'NB': 0.7394062078272604, 'GB': 0.7653171390013496, 'ADA': 0.7136302294197031}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'diabetes_4_of_4', 'KNN': 0.7086369770580296, 'LR': 0.7813765182186234, 'RF': 0.7340080971659919, 'NB': 0.7658569500674763, 'GB': 0.7337381916329285, 'ADA': 0.7342780026990553}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'symptoms_1_of_4', 'KNN': 0.9617886178861788, 'LR': 0.8699186991869918, 'RF': 0.983739837398374, 'NB': 0.8902439024390244, 'GB': 0.9829268292682928, 'ADA': 0.08617886178861789}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'symptoms_2_of_4', 'KNN': 0.9666666666666666, 'LR': 0.8829268292682928, 'RF': 0.9878048780487804, 'NB': 0.8707317073170733, 'GB': 0.983739837398374, 'ADA': 0.09268292682926829}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'symptoms_3_of_4', 'KNN': 0.9691056910569106, 'LR': 0.8902439024390244, 'RF': 0.98130081300813, 'NB': 0.8723577235772358, 'GB': 0.9772357723577236, 'ADA': 0.091869918699187}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'symptoms_4_of_4', 'KNN': 0.9552845528455286, 'LR': 0.8894308943089431, 'RF': 0.9764227642276422, 'NB': 0.8552845528455284, 'GB': 0.9747967479674797, 'ADA': 0.09024390243902439}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'stroke_1_of_4', 'KNN': 0.931936274509804, 'LR': 0.9499295343137255, 'RF': 0.9491421568627452, 'NB': 0.8529197303921568, 'GB': 0.9467922794117648, 'ADA': 0.9420955882352942}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'stroke_2_of_4', 'KNN': 0.9397579656862746, 'LR': 0.9507077205882354, 'RF': 0.9499234068627451, 'NB': 0.8717126225490196, 'GB': 0.940530024509804, 'ADA': 0.9467892156862746}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'stroke_3_of_4', 'KNN': 0.932668504901961, 'LR': 0.9483272058823531, 'RF': 0.9475398284313726, 'NB': 0.8676531862745097, 'GB': 0.9389399509803923, 'ADA': 0.9467585784313727}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'stroke_4_of_4', 'KNN': 0.9397089460784315, 'LR': 0.9498866421568628, 'RF': 0.951452205882353, 'NB': 0.8692187499999999, 'GB': 0.9428278186274511, 'ADA': 0.9420465686274511}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'hepatitisC_1_of_4', 'KNN': 0.8986206896551725, 'LR': 0.9255172413793102, 'RF': 0.9259770114942528, 'NB': 0.9188505747126436, 'GB': 0.9190804597701149, 'ADA': 0.7197701149425287}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'hepatitisC_2_of_4', 'KNN': 0.9048275862068966, 'LR': 0.9117241379310345, 'RF': 0.9521839080459771, 'NB': 0.9050574712643679, 'GB': 0.9255172413793102, 'ADA': 0.911264367816092}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'hepatitisC_3_of_4', 'KNN': 0.8912643678160919, 'LR': 0.9319540229885058, 'RF': 0.8910344827586207, 'NB': 0.8845977011494253, 'GB': 0.8777011494252873, 'ADA': 0.8777011494252873}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'hepatitisC_4_of_4', 'KNN': 0.9117241379310345, 'LR': 0.9255172413793102, 'RF': 0.9321839080459771, 'NB': 0.9324137931034484, 'GB': 0.939080459770115, 'ADA': 0.6645977011494252}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'heartDisease_1_of_4', 'KNN': 0.7304347826086957, 'LR': 0.7913043478260869, 'RF': 0.8217391304347826, 'NB': 0.8217391304347826, 'GB': 0.7956521739130435, 'ADA': 0.8043478260869564}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'heartDisease_2_of_4', 'KNN': 0.6521739130434783, 'LR': 0.8608695652173914, 'RF': 0.8913043478260871, 'NB': 0.8782608695652174, 'GB': 0.8739130434782609, 'ADA': 0.8130434782608695}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'heartDisease_3_of_4', 'KNN': 0.6981642512077295, 'LR': 0.8556521739130434, 'RF': 0.8685990338164251, 'NB': 0.8860869565217392, 'GB': 0.8470531400966184, 'ADA': 0.8296618357487923}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'heartDisease_4_of_4', 'KNN': 0.5894685990338164, 'LR': 0.8385507246376811, 'RF': 0.8255072463768116, 'NB': 0.8207729468599034, 'GB': 0.8385507246376811, 'ADA': 0.7906280193236715}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'indianLiver_1_of_4', 'KNN': 0.6992610837438423, 'LR': 0.8110837438423644, 'RF': 0.7194581280788178, 'NB': 0.7201970443349753, 'GB': 0.7056650246305419, 'ADA': 0.7059113300492611}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'indianLiver_2_of_4', 'KNN': 0.6078817733990147, 'LR': 0.6435960591133005, 'RF': 0.6637931034482759, 'NB': 0.6157635467980296, 'GB': 0.6283251231527094, 'ADA': 0.6714285714285715}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'indianLiver_3_of_4', 'KNN': 0.6270935960591133, 'LR': 0.7187192118226602, 'RF': 0.6620689655172414, 'NB': 0.5987684729064039, 'GB': 0.6546798029556651, 'ADA': 0.612807881773399}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'indianLiver_4_of_4', 'KNN': 0.6689655172413793, 'LR': 0.6903940886699508, 'RF': 0.6347290640394089, 'NB': 0.5926108374384237, 'GB': 0.641871921182266, 'ADA': 0.6847290640394089}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'wisconsin_1_of_4', 'KNN': 0.8950738916256157, 'LR': 0.9366995073891626, 'RF': 0.9300492610837438, 'NB': 0.9507389162561577, 'GB': 0.9165024630541871, 'ADA': 0.951231527093596}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'wisconsin_2_of_4', 'KNN': 0.8736453201970443, 'LR': 0.9504926108374384, 'RF': 0.9364532019704435, 'NB': 0.9293103448275863, 'GB': 0.8724137931034482, 'ADA': 0.9362068965517241}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'wisconsin_3_of_4', 'KNN': 0.9086206896551726, 'LR': 0.9440886699507389, 'RF': 0.9440886699507389, 'NB': 0.9435960591133004, 'GB': 0.9083743842364532, 'ADA': 0.9226600985221675}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'wisconsin_4_of_4', 'KNN': 0.9014778325123153, 'LR': 0.9374384236453203, 'RF': 0.9578817733990148, 'NB': 0.9716748768472907, 'GB': 0.9298029556650247, 'ADA': 0.9433497536945813}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'hypothyroid_1_of_4', 'KNN': 0.9062830572507992, 'LR': 0.9267364138331879, 'RF': 0.949351932577739, 'NB': 0.35562917756466145, 'GB': 0.9816506829410055, 'ADA': 0.9698169136878814}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'hypothyroid_2_of_4', 'KNN': 0.9062481836675385, 'LR': 0.9202615518744551, 'RF': 0.9288811392037198, 'NB': 0.3502063353676257, 'GB': 0.97196745132229, 'ADA': 0.9579598953792502}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'hypothyroid_3_of_4', 'KNN': 0.9083929090380704, 'LR': 0.9234873583260679, 'RF': 0.9461261261261262, 'NB': 0.37072362685265914, 'GB': 0.9762859633827377, 'ADA': 0.9752165068294101}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'hypothyroid_4_of_4', 'KNN': 0.9061609997093868, 'LR': 0.9180238302818948, 'RF': 0.9352804417320547, 'NB': 0.354954954954955, 'GB': 0.9762801511188609, 'ADA': 0.9654984016274339}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'framingham_1_of_4', 'KNN': 0.8337056386236714, 'LR': 0.8522968834444244, 'RF': 0.8490181949198343, 'NB': 0.8019696150843691, 'GB': 0.8380832282471626, 'ADA': 0.8281991232810905}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'framingham_2_of_4', 'KNN': 0.8085269921335495, 'LR': 0.8424608178706539, 'RF': 0.8479192938209332, 'NB': 0.8183750675553954, 'GB': 0.8435356992734041, 'ADA': 0.8260373506275146}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'framingham_3_of_4', 'KNN': 0.8315078364258692, 'LR': 0.8501110910946975, 'RF': 0.8446406052963429, 'NB': 0.82825316759743, 'GB': 0.8457455113192818, 'ADA': 0.8347865249504594}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'framingham_4_of_4', 'KNN': 0.8271602714225665, 'LR': 0.8446285954482675, 'RF': 0.8413559118477151, 'NB': 0.8140154927040173, 'GB': 0.8325827178286195, 'ADA': 0.8194559538821833}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'breastCancer_1_of_4', 'KNN': 0.8950738916256157, 'LR': 0.9366995073891626, 'RF': 0.9440886699507389, 'NB': 0.9507389162561577, 'GB': 0.9165024630541871, 'ADA': 0.951231527093596}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'breastCancer_2_of_4', 'KNN': 0.8736453201970443, 'LR': 0.9504926108374384, 'RF': 0.9293103448275861, 'NB': 0.9293103448275863, 'GB': 0.8793103448275863, 'ADA': 0.9362068965517241}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'breastCancer_3_of_4', 'KNN': 0.9086206896551726, 'LR': 0.9440886699507389, 'RF': 0.9440886699507389, 'NB': 0.9435960591133004, 'GB': 0.9083743842364532, 'ADA': 0.9364532019704435}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'breastCancer_4_of_4', 'KNN': 0.9014778325123153, 'LR': 0.9374384236453203, 'RF': 0.9576354679802955, 'NB': 0.9716748768472907, 'GB': 0.9155172413793103, 'ADA': 0.9433497536945813}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'autism_1_of_4', 'KNN': 0.6666666666666666, 'LR': 0.9870967741935484, 'RF': 1.0, 'NB': 0.9606451612903226, 'GB': 1.0, 'ADA': 1.0}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'autism_2_of_4', 'KNN': 0.6384946236559139, 'LR': 0.973548387096774, 'RF': 1.0, 'NB': 0.9212903225806454, 'GB': 1.0, 'ADA': 1.0}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'autism_3_of_4', 'KNN': 0.6709677419354838, 'LR': 1.0, 'RF': 1.0, 'NB': 0.96, 'GB': 1.0, 'ADA': 1.0}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'autism_4_of_4', 'KNN': 0.7365591397849462, 'LR': 0.9670967741935484, 'RF': 1.0, 'NB': 0.9610752688172044, 'GB': 1.0, 'ADA': 1.0}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'heartBeat_1_of_4', 'KNN': 0.9997248968363136, 'LR': 0.9733380443490484, 'RF': 0.9972516135858639, 'NB': 0.7589484105990296, 'GB': 0.9997248968363136, 'ADA': 0.9997248968363136}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'heartBeat_2_of_4', 'KNN': 1.0, 'LR': 0.9722383874722251, 'RF': 0.9953274029959036, 'NB': 0.7526115906102151, 'GB': 0.9994497936726272, 'ADA': 0.9994497936726272}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'heartBeat_3_of_4', 'KNN': 0.999175068397902, 'LR': 0.975263388605892, 'RF': 0.9964255483168826, 'NB': 0.7468366915065677, 'GB': 0.9994501715615882, 'ADA': 0.9994501715615882}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'heartBeat_4_of_4', 'KNN': 1.0, 'LR': 0.9725161358586393, 'RF': 0.9969768883111387, 'NB': 0.7842250253185604, 'GB': 1.0, 'ADA': 1.0}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'stress_1_of_4', 'KNN': 0.4743951612903226, 'LR': 1.0, 'RF': 1.0, 'NB': 1.0, 'GB': 0.9810483870967742, 'ADA': 0.6133064516129032}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'stress_2_of_4', 'KNN': 0.6453629032258064, 'LR': 1.0, 'RF': 1.0, 'NB': 1.0, 'GB': 0.99375, 'ADA': 0.5951612903225806}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'stress_3_of_4', 'KNN': 0.5477822580645161, 'LR': 1.0, 'RF': 0.9810483870967742, 'NB': 1.0, 'GB': 0.9810483870967742, 'ADA': 0.7268145161290324}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'stress_4_of_4', 'KNN': 0.5161290322580645, 'LR': 1.0, 'RF': 1.0, 'NB': 1.0, 'GB': 0.9870967741935484, 'ADA': 0.7897177419354839}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'fetalHealth_1_of_4', 'KNN': 0.8515253041791573, 'LR': 0.8834773408569918, 'RF': 0.9210192205960148, 'NB': 0.7669017809910069, 'GB': 0.9416681361311937, 'ADA': 0.8871627578910246}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'fetalHealth_2_of_4', 'KNN': 0.8721742197143361, 'LR': 0.8739904778698643, 'RF': 0.9059954152706755, 'NB': 0.7949920648915535, 'GB': 0.9191853288661612, 'ADA': 0.8551930876388644}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'fetalHealth_3_of_4', 'KNN': 0.8380708869687886, 'LR': 0.8888908481749251, 'RF': 0.9227825780285663, 'NB': 0.8059601481220244, 'GB': 0.937876917651208, 'ADA': 0.8454946217598307}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'fetalHealth_4_of_4', 'KNN': 0.8682242990654206, 'LR': 0.8776758949038971, 'RF': 0.9247222712043731, 'NB': 0.8210897548933168, 'GB': 0.9547875154293776, 'ADA': 0.8680832304708165}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'fetalCardio_1_of_4', 'KNN': 0.8026626697231528, 'LR': 0.7820313877622994, 'RF': 0.8477164521248456, 'NB': 0.7856286369247046, 'GB': 0.8702697936871804, 'ADA': 0.8365191324281434}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'fetalCardio_2_of_4', 'KNN': 0.8082701463586668, 'LR': 0.8102274731087992, 'RF': 0.8647681184976195, 'NB': 0.7800740610121673, 'GB': 0.8835302415799683, 'ADA': 0.823417386704285}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'fetalCardio_3_of_4', 'KNN': 0.8003703050608358, 'LR': 0.8418621054487744, 'RF': 0.8700405572209486, 'NB': 0.8455475224828073, 'GB': 0.8549991183212837, 'ADA': 0.8644507141597604}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'fetalCardio_4_of_4', 'KNN': 0.8248986069476283, 'LR': 0.845600423205784, 'RF': 0.8851877975665667, 'NB': 0.7551578204902133, 'GB': 0.8889613824722271, 'ADA': 0.8192205960148122}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'diabetes2019_1_of_4', 'KNN': 0.7060283687943262, 'LR': 0.8740248226950355, 'RF': 0.9031914893617021, 'NB': 0.8654255319148936, 'GB': 0.8781028368794328, 'ADA': 0.8659574468085106}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'diabetes2019_2_of_4', 'KNN': 0.6932624113475179, 'LR': 0.8825354609929079, 'RF': 0.8740248226950355, 'NB': 0.839982269503546, 'GB': 0.8568262411347518, 'ADA': 0.8695921985815602}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'diabetes2019_3_of_4', 'KNN': 0.7015070921985816, 'LR': 0.8318262411347519, 'RF': 0.8447695035460994, 'NB': 0.81072695035461, 'GB': 0.8152482269503546, 'ADA': 0.7858156028368795}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'diabetes2019_4_of_4', 'KNN': 0.7056737588652482, 'LR': 0.8909574468085106, 'RF': 0.886436170212766, 'NB': 0.8318262411347519, 'GB': 0.8698581560283689, 'ADA': 0.8652482269503545}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'thoracic_1_of_4', 'KNN': 0.7782608695652173, 'LR': 0.8057971014492754, 'RF': 0.8394927536231884, 'NB': 0.3666666666666667, 'GB': 0.7960144927536232, 'ADA': 0.7195652173913043}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'thoracic_2_of_4', 'KNN': 0.8054347826086957, 'LR': 0.8228260869565217, 'RF': 0.8307971014492754, 'NB': 0.3282608695652174, 'GB': 0.7797101449275363, 'ADA': 0.730072463768116}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'thoracic_3_of_4', 'KNN': 0.8126811594202898, 'LR': 0.8293478260869565, 'RF': 0.8467391304347827, 'NB': 0.5347826086956522, 'GB': 0.8028985507246377, 'ADA': 0.803623188405797}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'thoracic_4_of_4', 'KNN': 0.7949275362318841, 'LR': 0.8297101449275364, 'RF': 0.863768115942029, 'NB': 0.5123188405797102, 'GB': 0.8297101449275364, 'ADA': 0.7865942028985506}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'cervicalCancer_1_of_4', 'KNN': 0.9395348837209301, 'LR': 0.930232558139535, 'RF': 0.9534883720930232, 'NB': 0.39069767441860465, 'GB': 0.944186046511628, 'ADA': 0.9348837209302326}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'cervicalCancer_2_of_4', 'KNN': 0.930232558139535, 'LR': 0.9255813953488372, 'RF': 0.9534883720930232, 'NB': 0.9116279069767442, 'GB': 0.9441860465116279, 'ADA': 0.9488372093023255}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'cervicalCancer_3_of_4', 'KNN': 0.939313399778516, 'LR': 0.9344407530454042, 'RF': 0.9440753045404208, 'NB': 0.8456256921373202, 'GB': 0.9346622369878184, 'ADA': 0.9392026578073089}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'cervicalCancer_4_of_4', 'KNN': 0.9207087486157253, 'LR': 0.939313399778516, 'RF': 0.9346622369878184, 'NB': 0.8465116279069769, 'GB': 0.9346622369878184, 'ADA': 0.9207087486157255}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'epilepsy_1_of_4', 'KNN': 0.9060869565217391, 'LR': 0.6038260869565217, 'RF': 0.9673043478260869, 'NB': 0.9624347826086957, 'GB': 0.9558260869565217, 'ADA': 0.9481739130434782}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'epilepsy_2_of_4', 'KNN': 0.9036521739130435, 'LR': 0.6059130434782609, 'RF': 0.9652173913043478, 'NB': 0.9502608695652175, 'GB': 0.9547826086956521, 'ADA': 0.936695652173913}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'epilepsy_3_of_4', 'KNN': 0.9040000000000001, 'LR': 0.6149565217391304, 'RF': 0.9645217391304348, 'NB': 0.9589565217391304, 'GB': 0.9554782608695651, 'ADA': 0.942608695652174}
# KNN
# LR
# RF
# NB
# GB
# ADA
# {'dataset': 'epilepsy_4_of_4', 'KNN': 0.8980869565217391, 'LR': 0.6052173913043479, 'RF': 0.9645217391304348, 'NB': 0.958608695652174, 'GB': 0.9554782608695653, 'ADA': 0.9415652173913042}

# %%
performances_df = pd.DataFrame(performances)
performances_df
# Out:
#                   dataset       KNN        LR        RF        NB        GB  \
# 0         diabetes_1_of_4  0.713360  0.780297  0.748988  0.769906  0.749258
# 1         diabetes_2_of_4  0.713360  0.713630  0.750742  0.755466  0.734683
# 2         diabetes_3_of_4  0.723887  0.750202  0.770985  0.739406  0.765317
# 3         diabetes_4_of_4  0.708637  0.781377  0.734008  0.765857  0.733738
# 4         symptoms_1_of_4  0.961789  0.869919  0.983740  0.890244  0.982927
# ..                    ...       ...       ...       ...       ...       ...
# 71  cervicalCancer_4_of_4  0.920709  0.939313  0.934662  0.846512  0.934662
# 72        epilepsy_1_of_4  0.906087  0.603826  0.967304  0.962435  0.955826
# 73        epilepsy_2_of_4  0.903652  0.605913  0.965217  0.950261  0.954783
# 74        epilepsy_3_of_4  0.904000  0.614957  0.964522  0.958957  0.955478
# 75        epilepsy_4_of_4  0.898087  0.605217  0.964522  0.958609  0.955478
#
#          ADA
# 0   0.744399
# 1   0.713900
# 2   0.713630
# 3   0.734278
# 4   0.086179
# ..       ...
# 71  0.920709
# 72  0.948174
# 73  0.936696
# 74  0.942609
# 75  0.941565
#
# [76 rows x 7 columns]

# %%
def reorder(row, columns):
    sorted_index = row.loc[columns].sort_values(ascending=False).index
    new_columns = [f'v{i}' for i in range(1, len(sorted_index) + 1)]
    return pd.Series(sorted_index.values, index=new_columns)

# %%
performance_df_sorted = performances_df.apply(reorder, axis=1, columns=performances_df.columns[1:])
performance_df_sorted = pd.concat([performances_df[['dataset']], performance_df_sorted], axis=1)
performance_df_sorted
# Out:
#                   dataset  v1  v2   v3   v4   v5   v6
# 0         diabetes_1_of_4  LR  NB   GB   RF  ADA  KNN
# 1         diabetes_2_of_4  NB  RF   GB  ADA   LR  KNN
# 2         diabetes_3_of_4  RF  GB   LR   NB  KNN  ADA
# 3         diabetes_4_of_4  LR  NB  ADA   RF   GB  KNN
# 4         symptoms_1_of_4  RF  GB  KNN   NB   LR  ADA
# ..                    ...  ..  ..  ...  ...  ...  ...
# 71  cervicalCancer_4_of_4  LR  RF   GB  ADA  KNN   NB
# 72        epilepsy_1_of_4  RF  NB   GB  ADA  KNN   LR
# 73        epilepsy_2_of_4  RF  GB   NB  ADA  KNN   LR
# 74        epilepsy_3_of_4  RF  NB   GB  ADA  KNN   LR
# 75        epilepsy_4_of_4  RF  NB   GB  ADA  KNN   LR
#
# [76 rows x 7 columns]

# %%
performance_df_sorted['v1'].value_counts()
# Out:
# RF     28
# LR     25
# GB     13
# NB      4
# ADA     3
# KNN     3
# Name: v1, dtype: int64

# %%
performances_df.to_csv(f'../performances/splitted/1_of_{n_splits}.csv',index=False)
performance_df_sorted.to_csv(f'../performances/splitted/1_of_{n_splits}_sort.csv',index=False)
