# %%
import pandas as pd

# %%
perfomance_splits = [1,2,4,10]

# %%
def filterSplits(df):
    return df[df['dataset'].str.contains('_1_of_')]

# %%
concatenated_filtered_performances = pd.concat([filterSplits(pd.read_csv(f'../performances/splitted/1_of_{split}.csv')) for split in perfomance_splits], ignore_index=True)
concatenated_filtered_performances
# Out:
#                  dataset       KNN        LR        RF        NB        GB  \
# 0        covid19_1_of_69  0.934658  0.939133  0.944990  0.906496  0.950583
# 1        diabetes_1_of_1  0.700552  0.757907  0.759155  0.752636  0.756557
# 2        symptoms_1_of_1  0.991260  0.903049  0.991463  0.880488  0.990244
# 3          stroke_1_of_1  0.937573  0.950685  0.950098  0.865753  0.949902
# 4      hepatitisC_1_of_1  0.933797  0.949080  0.942257  0.928698  0.945632
# ..                   ...       ...       ...       ...       ...       ...
# 77     heartBeat_1_of_10  0.999313  0.960865  0.988330  0.759627  1.000000
# 78   fetalHealth_1_of_10  0.821705  0.849945  0.891916  0.746622  0.905980
# 79   fetalCardio_1_of_10  0.774862  0.764895  0.812071  0.755925  0.812182
# 80  diabetes2019_1_of_10  0.614211  0.813158  0.834737  0.823158  0.823684
# 81      epilepsy_1_of_10  0.881739  0.547826  0.956522  0.960870  0.954783
#
#          ADA
# 0   0.946437
# 1   0.735702
# 2   0.090244
# 3   0.950881
# 4   0.927017
# ..       ...
# 77  1.000000
# 78  0.840310
# 79  0.812292
# 80  0.792632
# 81  0.951304
#
# [82 rows x 7 columns]

# %%
#concatenated_filtered_performances.drop(['NB','KNN'],inplace=True)

# %%
def reorder(row, columns):
    sorted_index = row.loc[columns].sort_values(ascending=False).index
    new_columns = [f'v{i}' for i in range(1, len(sorted_index) + 1)]
    return pd.Series(sorted_index.values, index=new_columns)

# %%
performance_df_sorted = concatenated_filtered_performances.apply(reorder, axis=1, columns=concatenated_filtered_performances.columns[1:])
performance_df_sorted = pd.concat([concatenated_filtered_performances[['dataset']], performance_df_sorted], axis=1)
performance_df_sorted
# Out:
#                  dataset   v1   v2   v3   v4   v5   v6
# 0        covid19_1_of_69   GB  ADA   RF   LR  KNN   NB
# 1        diabetes_1_of_1   RF   LR   GB   NB  ADA  KNN
# 2        symptoms_1_of_1   RF  KNN   GB   LR   NB  ADA
# 3          stroke_1_of_1  ADA   LR   RF   GB  KNN   NB
# 4      hepatitisC_1_of_1   LR   GB   RF  KNN   NB  ADA
# ..                   ...  ...  ...  ...  ...  ...  ...
# 77     heartBeat_1_of_10   GB  ADA  KNN   RF   LR   NB
# 78   fetalHealth_1_of_10   GB   RF   LR  ADA  KNN   NB
# 79   fetalCardio_1_of_10  ADA   GB   RF  KNN   LR   NB
# 80  diabetes2019_1_of_10   RF   GB   NB   LR  ADA  KNN
# 81      epilepsy_1_of_10   NB   RF   GB  ADA  KNN   LR
#
# [82 rows x 7 columns]

# %%
performance_df_sorted['v1'].value_counts()
# Out:
# RF     32
# LR     19
# GB     15
# ADA     9
# NB      4
# KNN     3
# Name: v1, dtype: int64

# %%
pd.set_option('display.max_rows', None)

# %%
performance_df_sorted.sort_values(by='dataset',inplace=True)
performance_df_sorted
# Out:
#                     dataset   v1   v2   v3   v4   v5   v6
# 13      appendicitis_1_of_1   NB  ADA   RF   GB   LR  KNN
# 27  arrhythmiaBinary_1_of_6   RF   GB  ADA  KNN   LR   NB
# 18            autism_1_of_1   RF   GB  ADA   LR   NB  KNN
# 44            autism_1_of_2   RF   GB  ADA   LR   NB  KNN
# 63            autism_1_of_4   RF   GB  ADA   LR   NB  KNN
# 16      breastCancer_1_of_1  ADA   RF   LR   GB   NB  KNN
# 43      breastCancer_1_of_2   LR  ADA   RF   GB   NB  KNN
# 62      breastCancer_1_of_4  ADA   NB   RF   LR   GB  KNN
# 8      cardioDisease_1_of_4   GB  ADA   NB   RF   LR  KNN
# 28    cervicalCancer_1_of_1   LR   GB   RF  ADA  KNN   NB
# 51    cervicalCancer_1_of_2   GB  ADA   LR   RF  KNN   NB
# 70    cervicalCancer_1_of_4   RF   GB  KNN  ADA   LR   NB
# 5          cirrhosis_1_of_1   RF   NB   LR   GB  ADA  KNN
# 34         cirrhosis_1_of_2   RF   NB   LR   GB  ADA  KNN
# 0           covid19_1_of_69   GB  ADA   RF   LR  KNN   NB
# 24      diabetes2019_1_of_1   RF   GB   LR  ADA   NB  KNN
# 80     diabetes2019_1_of_10   RF   GB   NB   LR  ADA  KNN
# 49      diabetes2019_1_of_2   RF   GB   LR  ADA   NB  KNN
# 68      diabetes2019_1_of_4   RF   GB   LR  ADA   NB  KNN
# 1           diabetes_1_of_1   RF   LR   GB   NB  ADA  KNN
# 30          diabetes_1_of_2   LR   NB   RF   GB  ADA  KNN
# 53          diabetes_1_of_4   LR   NB   GB   RF  ADA  KNN
# 29          epilepsy_1_of_1   RF   GB   NB  ADA  KNN   LR
# 81         epilepsy_1_of_10   NB   RF   GB  ADA  KNN   LR
# 52          epilepsy_1_of_2   RF   GB   NB  ADA  KNN   LR
# 71          epilepsy_1_of_4   RF   NB   GB  ADA  KNN   LR
# 23       fetalCardio_1_of_1   RF   GB  KNN  ADA   NB   LR
# 79      fetalCardio_1_of_10  ADA   GB   RF  KNN   LR   NB
# 48       fetalCardio_1_of_2   GB   RF  KNN  ADA   LR   NB
# 67       fetalCardio_1_of_4   GB   RF  ADA  KNN   NB   LR
# 22       fetalHealth_1_of_1   GB   RF  ADA  KNN   LR   NB
# 78      fetalHealth_1_of_10   GB   RF   LR  ADA  KNN   NB
# 47       fetalHealth_1_of_2   GB   RF  ADA   LR  KNN   NB
# 66       fetalHealth_1_of_4   GB   RF  ADA   LR  KNN   NB
# 14        framingham_1_of_1   LR   RF   GB  ADA   NB  KNN
# 76       framingham_1_of_10   LR   RF   GB  KNN   NB  ADA
# 41        framingham_1_of_2   LR   RF   GB  ADA   NB  KNN
# 61        framingham_1_of_4   LR   RF   GB  KNN  ADA   NB
# 17        heart2020_1_of_21  ADA   LR   NB   GB   RF  KNN
# 20         heartBeat_1_of_1  KNN   GB  ADA   RF   LR   NB
# 77        heartBeat_1_of_10   GB  ADA  KNN   RF   LR   NB
# 45         heartBeat_1_of_2   GB  ADA  KNN   RF   LR   NB
# 64         heartBeat_1_of_4  KNN   GB  ADA   RF   LR   NB
# 10   heartCleaveland_1_of_1   NB   LR   RF  ADA   GB  KNN
# 38   heartCleaveland_1_of_2   NB   LR   RF   GB  ADA  KNN
# 6       heartDisease_1_of_1   RF   GB  ADA   NB   LR  KNN
# 74     heartDisease_1_of_10   LR   NB  ADA   RF  KNN   GB
# 35      heartDisease_1_of_2   RF   GB   NB  ADA   LR  KNN
# 57      heartDisease_1_of_4   RF   NB  ADA   GB   LR  KNN
# 7       heartFailure_1_of_1   RF   GB   LR  ADA   NB  KNN
# 36      heartFailure_1_of_2   RF   LR   GB  ADA   NB  KNN
# 4         hepatitisC_1_of_1   LR   GB   RF  KNN   NB  ADA
# 33        hepatitisC_1_of_2   RF   GB   LR   NB  KNN  ADA
# 56        hepatitisC_1_of_4   RF   LR   GB   NB  KNN  ADA
# 12       hypothyroid_1_of_1   GB  ADA   RF   LR  KNN   NB
# 75      hypothyroid_1_of_10  ADA   GB   RF   LR  KNN   NB
# 40       hypothyroid_1_of_2   GB  ADA   RF   LR  KNN   NB
# 60       hypothyroid_1_of_4   GB  ADA   RF   LR  KNN   NB
# 9        indianLiver_1_of_1   LR   RF   GB  ADA  KNN   NB
# 37       indianLiver_1_of_2  ADA   LR   GB   RF  KNN   NB
# 58       indianLiver_1_of_4   LR   NB   RF  ADA   GB  KNN
# 15         lowerback_1_of_1   LR   RF  KNN   GB  ADA   NB
# 42         lowerback_1_of_2   RF   GB  ADA   LR  KNN   NB
# 19           obesity_1_of_1   GB   RF   NB  ADA   LR  KNN
# 26           preterm_1_of_1  KNN   LR   RF   GB  ADA   NB
# 21            stress_1_of_1   LR   NB   RF   GB  KNN  ADA
# 46            stress_1_of_2   LR   NB   RF   GB  KNN  ADA
# 65            stress_1_of_4   LR   RF   NB   GB  ADA  KNN
# 3             stroke_1_of_1  ADA   LR   RF   GB  KNN   NB
# 73           stroke_1_of_10   RF   LR  KNN   GB  ADA   NB
# 32            stroke_1_of_2   LR   RF  ADA   GB  KNN   NB
# 55            stroke_1_of_4   LR   RF   GB  ADA  KNN   NB
# 2           symptoms_1_of_1   RF  KNN   GB   LR   NB  ADA
# 72         symptoms_1_of_10   RF   GB  KNN   NB   LR  ADA
# 31          symptoms_1_of_2   RF   GB  KNN   LR   NB  ADA
# 54          symptoms_1_of_4   RF   GB  KNN   NB   LR  ADA
# 25          thoracic_1_of_1   RF   LR  ADA   GB  KNN   NB
# 50          thoracic_1_of_2   RF   LR  KNN  ADA   GB   NB
# 69          thoracic_1_of_4   RF   LR   GB  KNN  ADA   NB
# 11         wisconsin_1_of_1  ADA   RF   LR   GB   NB  KNN
# 39         wisconsin_1_of_2   LR  ADA   GB   RF   NB  KNN
# 59         wisconsin_1_of_4  ADA   NB   LR   RF   GB  KNN
